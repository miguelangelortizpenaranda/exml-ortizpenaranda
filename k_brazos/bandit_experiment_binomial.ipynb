# %% [markdown]
# <a href="https://colab.research.google.com/github/miguelangelortizpenaranda/ortizpastorserna/blob/main/bandit_experiment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Grupo 1: Bandido de K-Brazos (Distribución binomial general)
#
# Autores:
#
# - Miguel Ángel Ortiz Peñaranda
# - Miguel Pastor Beltrá
# - Rubén Serna
#
# ## Introducción
#
# El bandido de k-brazos, o k-armed bandit, supone un problema clásico de aprendizaje por refuerzo. En él, disponemos de un número K de elementos que, al activarlos, nos otorgan una recompensa determinada, desconocida a priori. Es esta recompensa la que nos interesa maximizar a lo largo del tiempo, por medio de un método que, bien explore distintos "brazos" o soluciones, bien explote la solución que en un momento dado parezca la mejor, o bien mediante un compendio de ambas prácticas.

# %% [markdown]
# ## Preparación del entorno
#
# Para el funcionamiento de este notebook por parte de Colab, es necesario ejecutar las líneas de código que se encuentran a continuación,
# las cuales se encargan de clonar el repositorio para que el código esté disponible por parte de este notebook.

# %%
#!rm -r ortizpastorserna/
#!git clone https://github.com/miguelangelortizpenaranda/ortizpastorserna.git
#!cd ortizpastorserna/

# %% [markdown]
# A continuación añadimos al path los directorios de código fuente, tanto para ejecución en Colab como para ejecución en un IDE local.

# %%
#@title Importamos todas las clases y funciones
import sys


# Añadir los directorios fuentes al path de Python
sys.path.append('/content/ortizpastorserna/src/eml_k_bandit')
sys.path.append('src/eml_k_bandit')

# Verificar que se han añadido correctamente
print(sys.path)

#!ls
# Out:
# ['/home/miguel/.local/share/JetBrains/pycharm-2025.2.4/plugins/python-ce/helpers/jupyter_debug', '/home/miguel/.local/share/JetBrains/pycharm-2025.2.4/plugins/python-ce/helpers/pydev', '/home/miguel/PycharmProjects/exml-ortizpenaranda', '/usr/lib/python314.zip', '/usr/lib/python3.14', '/usr/lib/python3.14/lib-dynload', '', '/home/miguel/PycharmProjects/exml-ortizpenaranda/.venv/lib/python3.14/site-packages', '/content/ortizpastorserna/src/eml_k_bandit', 'src/eml_k_bandit', '/content/ortizpastorserna/src/eml_k_bandit', 'src/eml_k_bandit']

# %% [markdown]
# Realizamos los imports correspondientes a los tipos implementados de variantes del bandido de k-brazos, así como los algoritmos que se han modelado, y algunas otras librerías adicionales para representación de los resultados.

# %%
import numpy as np
from typing import List

from algorithms import Algorithm, EpsilonGreedy, UCB1, Softmax
from arms import ArmBinomial, Bandit
from plotting import get_algorithm_label, plot_average_rewards, plot_optimal_selections, plot_regret
from util import get_results_average, convert_results

# %% [markdown]
# ## Metodología de trabajo
#
# Se propone una metodología de trabajo en la que se va a probar, tanto con distintas variantes del bandido de K-brazos (Testearemos parámetros como número de brazos o desviación), como con distintas variantes de los algoritmos que determinan en qué medida el bandido lleva a cabo una función de exploración o de explotación de los brazos, de cara a conseguir la mayor recompensa a lo largo del tiempo. Siendo así, seguiremos los siguientes pasos:
#
# 1. En cada experimento que se haga con el bandido, compararemos los algoritmos implementados (Epsilon-Greddy, UCB, Softmax), variando sus parámetros principales. Estos parámetros serán siempre iguales entre distintas ejecuciones, para asegurar la consistencia en el comportamiento de los mismos.
# 2. Se realizarán variaciones entre: Número de pasos (steps), número de brazos (k), y valor de la desviación en la distribución normal del bandido.
# 3. Para cada ejecución, se comparará el comportamiento de cada variante del algoritmo atendiendo a las métricas de: Porcentaje de elecciones óptimas en el 20% último de pasos (donde el algoritmo debe acercarse mayormente a la convergencia), y rechazo acumulado para ese algoritmo al final de la ejecución. La cantidad de pasos finales a tener en cuenta para el porcentaje de elecciones óptimas la hemos considerado así para quitarnos el tramo iniciar de los algoritmos donde el comportamiento sea mayoritariamente exploratorio.
# 4. Para cada experimento, se dará una valoración de los resultados obtenidos.
# 5. Finalmente, se darán unas conclusiones finales que indiquen qué algoritmo o algoritmos se considera que presentan un mejor comportamiento.

# %% [markdown]
# Fijamos la semilla aleatoria para asegurar la reproducibilidad de los resultados de las ejecuciones en distintos dispositivos.

# %%
seed = 1234
np.random.seed(seed)  # Fijar la semilla para reproducibilidad

runs = 200 # El número de ejecuciones que utilizamos para promediar resultados va a ser siempre constante en nuestros experimentos

# %% [markdown]
# ## Experimento
#
# Este código se encarga de ejecutar un número de `runs` concretos para el problema de k-armed bandit. Utilizando una lista de algoritmos y ejecutando cada algoritmo una serie de pasos, para acabar obteniendo un promedio de recompensas por ejecución, así como el porcentaje de selecciones del brazo óptimo para dichas ejecuciones.

# %%
def run_experiment(bandit: Bandit, algorithms: List[Algorithm], steps: int, runs: int):

    """
    Ejecuta el problema del bandido de k-brazos un número de runs concretos, una serie de pasos para cada algoritmo especificado.
    :param bandit: Implementación del bandido de k-brazos a ejecutar
    :param algorithms: Listado de algoritmos a ejecutar para esa implementación del bandido
    :param steps: Número de pasos a ejecutar para cada algoritmo individual
    :param runs: Número de ejecuciones independientes que se va a hacer para todos y cada uno de los algoritmos
    :return: Promedio de recompensas, arrepentimiento acumulado, y porcentaje de soluciones óptimas
    """
    optimal_arm = bandit.optimal_arm  # Se elige el brazo óptimo en base a la implementación del bandido. Necesario para calcular el porcentaje de selecciones óptimas.
    rewards = np.zeros((len(algorithms), steps)) # Matriz para almacenar las recompensas promedio.
    regrets = np.zeros((len(algorithms), steps)) # Matriz para almacenar el regret
    optimal_selections = np.zeros((len(algorithms), steps))  # Matriz para almacenar el porcentaje de selecciones óptimas.

    np.random.seed(seed)  # Asegurar reproducibilidad de resultados.

    for run in range(runs):
        current_bandit = Bandit(arms=bandit.arms) # Crea una instancia nueva del bandido con la distribución que especifica la implementación pasada como parámetro (normal, binomial)

        for algo in algorithms:
            algo.reset() # Reiniciar los valores de los algoritmos.

        total_rewards_per_algo = np.zeros(len(algorithms)) # Acumulador de recompensas por algoritmo. Necesario para calcular el promedio.

        for step in range(steps):
            for idx, algo in enumerate(algorithms):
                chosen_arm = algo.select_arm() # Seleccionar un brazo según la política del algoritmo.
                reward = current_bandit.pull_arm(chosen_arm) # Obtener la recompensa del brazo seleccionado.
                algo.update(chosen_arm, reward) # Actualizar el valor estimado del brazo seleccionado.

                optimal_reward = bandit.arms[optimal_arm].get_expected_value() # Recompensa óptima, para calcular regret

                rewards[idx, step] += reward # Acumular la recompensa obtenida en la matriz rewards para el algoritmo idx en el paso step.
                regrets[idx, step] += (optimal_reward - reward) # Acumulamos arrepentimiento como diferencia entre recompensa óptima y la obtenida
                total_rewards_per_algo[idx] += reward # Acumular la recompensa obtenida en total_rewards_per_algo para el algoritmo idx.

                 # Modificamos optimal_selections cuando el brazo elegido se corresponda con el brazo óptimo optimal_arm
                if chosen_arm == optimal_arm:
                  optimal_selections[idx, step] += 1

    # Promediamos recompensas entre ejecuciones
    rewards /= runs

    # Promediamos arrepentimientos entre ejecuciones
    regrets /= runs
    # Calculamos arrepentimiento acumulado a lo largo del array
    cumulative_regret = np.cumsum(regrets, axis=1)

    # Calculamos el porcentaje de selecciones óptimas y almacenar en optimal_selections
    optimal_selections /= runs
    optimal_selections *= 100

    total_steps = optimal_selections.shape[1]
    final_performance = optimal_selections[:, int(total_steps * 0.8):]
    avg_optimal_rates = np.mean(final_performance, axis=1)

    total_regret = cumulative_regret[:, -1] # Coge el ultimo valor

    # Mostrar resultados
    for i, rate in enumerate(avg_optimal_rates):
        print(f"Algoritmo {get_algorithm_label(algorithms[i])}: {rate:.2f}% de elecciones óptimas en el 20% último de steps")
        print(f"Algoritmo {get_algorithm_label(algorithms[i])}: {total_regret[i]:.2f} de arrepentimiento acumulado\n")

    return rewards, cumulative_regret, optimal_selections, avg_optimal_rates, total_regret

# %% [markdown]
# ## Ejecución del experimento
#
# A continuación, utilizando la función definida anteriormente, vamos a ejecutar el experimento del bandido. Esto se va a realizar para la variante del bandido con distribución binomial, con una probabilidad entre 0.1 y 0.9 por brazo, y recompensa máxima = 10 por brazo.
#
# Adicionalmente, se va a probar con una serie de algoritmos:
# - Epsilon Greedy, con valores de epsilon=[0, 0.01, 0.1], que determinan un comportamiento exploratorio cada vez mayor.
# - UCB-1, con c=0.5, c=1, c=2, que determina también el peso de la componente exploratoria en el algoritmo.
# - Softmax, con una temperatura de 0.5
#
# Estos algoritmos se van a probar para cada variante del experimento, y mostraremos el promedio de recompensa y el porcentaje de decisiones acertadas para el mejor brazo en cada caso.
#
# Vamos a crear, asimismo, una función que nos permitirá ejecutar el experimento para distinto número de brazos, y distinto número de ejecuciones, para ver si el comportamiento de los algoritmos cambia al modificar estos parámetros

# %%
def execute_bandit_experiment(k: int, steps: int, runs: int, bandit: Bandit):
    """
    Ejecuta el experimento para un bandido pasado como parámetro, teniendo en cuenta el número de brazos, cuántas ejecuciones
    queremos promediar, y el número de pasos para los que se va a probar el algoritmo.
    :param k: número de brazos del bandido
    :param steps: número de pasos en los que se va a ejecutar el algoritmo
    :param runs: número de ejecuciones para realizar un promedio de los resultados
    :param bandit: bandido para el que vamos a realizar el experimento
    """
    # Definir los algoritmos a comparar. En este caso son 3 algoritmos epsilon-greedy con diferentes valores de epsilon.
    algorithms = [EpsilonGreedy(k=k, epsilon=0), EpsilonGreedy(k=k, epsilon=0.01), EpsilonGreedy(k=k, epsilon=0.1), UCB1(k=k, c=0.5), UCB1(k=k, c=1), UCB1(k=k, c=2), Softmax(k=k, temperature=0.5), Softmax(k=k, temperature=1), Softmax(k=k, temperature=2)]

    print(bandit)
    optimal_arm = bandit.optimal_arm
    print(f"Optimal arm for bandit is: {optimal_arm + 1} with expected reward={bandit.get_expected_value(optimal_arm)}\n")
    rewards, regrets, optimal_selections, avg_optimal_rates, total_regret = run_experiment(bandit, algorithms, steps, runs)  # Ejecutar el experimento y obtener las recompensas promedio y promedio de las selecciones óptimas
    results = convert_results(algorithms=algorithms, avg_optimal_rates=avg_optimal_rates, total_regret=total_regret)
    # Graficar los resultados
    plot_optimal_selections(steps, optimal_selections, algorithms)
    plot_average_rewards(steps, rewards, algorithms)
    plot_regret(steps, regrets, algorithms)

    return results

# %% [markdown]
# ## Ejecución del experimento para Variante 1 del bandido
#
# En primer lugar, vamos a realizar el experimento para una variante del bandido de 10 brazos, con distribución binomial general donde la recompensa máxima es 10.

# %%
# Definimos el bandido (se comparte entre experimentos)
bandit = Bandit(arms=ArmBinomial.generate_arms(k=10, n=10)) # Generar un bandido con k brazos de distribución binomial. El valor de máxima recompensa será 10

# %% [markdown]
# ### Ejecución de los algoritmos para 1000 steps
#
# Nos disponemos a ejecutar el experimento para 1000 pasos inicialmente.

# %%
results_ex1_1 = execute_bandit_experiment(k=10, steps=1000, runs=runs, bandit = bandit)
# Out:
# Bandit with 10 arms: ArmBinomial(n=10, p=0.25), ArmBinomial(n=10, p=0.6), ArmBinomial(n=10, p=0.45), ArmBinomial(n=10, p=0.72), ArmBinomial(n=10, p=0.73), ArmBinomial(n=10, p=0.32), ArmBinomial(n=10, p=0.74), ArmBinomial(n=10, p=0.87), ArmBinomial(n=10, p=0.8), ArmBinomial(n=10, p=0.39)
# Optimal arm for bandit is: 8 with expected reward=8.7
#
# Algoritmo EpsilonGreedy (epsilon=0): 85.50% de elecciones óptimas en el 20% último de steps
# Algoritmo EpsilonGreedy (epsilon=0): 180.09 de arrepentimiento acumulado
#
# Algoritmo EpsilonGreedy (epsilon=0.01): 54.86% de elecciones óptimas en el 20% último de steps
# Algoritmo EpsilonGreedy (epsilon=0.01): 1485.67 de arrepentimiento acumulado
#
# Algoritmo EpsilonGreedy (epsilon=0.1): 89.66% de elecciones óptimas en el 20% último de steps
# Algoritmo EpsilonGreedy (epsilon=0.1): 487.68 de arrepentimiento acumulado
#
# Algoritmo UCB1 (c=0.5): 96.91% de elecciones óptimas en el 20% último de steps
# Algoritmo UCB1 (c=0.5): 68.84 de arrepentimiento acumulado
#
# Algoritmo UCB1 (c=1): 98.78% de elecciones óptimas en el 20% último de steps
# Algoritmo UCB1 (c=1): 73.10 de arrepentimiento acumulado
#
# Algoritmo UCB1 (c=2): 95.22% de elecciones óptimas en el 20% último de steps
# Algoritmo UCB1 (c=2): 202.07 de arrepentimiento acumulado
#
# Algoritmo Softmax (temperature=0.5): 14.00% de elecciones óptimas en el 20% último de steps
# Algoritmo Softmax (temperature=0.5): 1661.24 de arrepentimiento acumulado
#
# Algoritmo Softmax (temperature=1): 38.60% de elecciones óptimas en el 20% último de steps
# Algoritmo Softmax (temperature=1): 914.09 de arrepentimiento acumulado
#
# Algoritmo Softmax (temperature=2): 26.86% de elecciones óptimas en el 20% último de steps
# Algoritmo Softmax (temperature=2): 1291.99 de arrepentimiento acumulado
#
# Algoritmo EpsilonGreedy (epsilon=0): 85.50% de elecciones óptimas en el 20% último de steps
# Algoritmo EpsilonGreedy (epsilon=0): 180.09 de arrepentimiento acumulado
#
# Algoritmo EpsilonGreedy (epsilon=0.01): 54.86% de elecciones óptimas en el 20% último de steps
# Algoritmo EpsilonGreedy (epsilon=0.01): 1485.67 de arrepentimiento acumulado
#
# Algoritmo EpsilonGreedy (epsilon=0.1): 89.66% de elecciones óptimas en el 20% último de steps
# Algoritmo EpsilonGreedy (epsilon=0.1): 487.68 de arrepentimiento acumulado
#
# Algoritmo UCB1 (c=0.5): 96.91% de elecciones óptimas en el 20% último de steps
# Algoritmo UCB1 (c=0.5): 68.84 de arrepentimiento acumulado
#
# Algoritmo UCB1 (c=1): 98.78% de elecciones óptimas en el 20% último de steps
# Algoritmo UCB1 (c=1): 73.10 de arrepentimiento acumulado
#
# Algoritmo UCB1 (c=2): 95.22% de elecciones óptimas en el 20% último de steps
# Algoritmo UCB1 (c=2): 202.07 de arrepentimiento acumulado
#
# Algoritmo Softmax (temperature=0.5): 14.00% de elecciones óptimas en el 20% último de steps
# Algoritmo Softmax (temperature=0.5): 1661.24 de arrepentimiento acumulado
#
# Algoritmo Softmax (temperature=1): 38.60% de elecciones óptimas en el 20% último de steps
# Algoritmo Softmax (temperature=1): 914.09 de arrepentimiento acumulado
#
# Algoritmo Softmax (temperature=2): 26.86% de elecciones óptimas en el 20% último de steps
# Algoritmo Softmax (temperature=2): 1291.99 de arrepentimiento acumulado

# %% [markdown]
# ### Valoración de los resultados
#
# Como se puede ver en las estadísticas y el las gráficas, las variantes de UCB-1 son las que presentan un mejor comportamiento, sobre todo aquellas para c=0.1 y c=1, sobre todo este último, quedando bastante cerca del 100% de aciertos, seguido moderadamente por el algoritmo Epsilon-Greedy con una componente exploratoria de 0.1.
#
# Vemos como Epsilon-Greedy cop epsilon=0 se estanca en una solución subóptima, y como la variante con epsilon=0.01 tarda bastante en acercarse al mejor brazo.
#
# Softmax parece que ofrece un funcionamiento bastante pobre en comparación al resto.
#
# Concluímos, fijándonos en el mayor porcentaje de aciertos vs menor arrepentimiento acumulado, que UCB-1 con c=0.5 es el que mejor se ha comportado.

# %% [markdown]
# ### Ejecución de los algoritmos para 2000 steps
#
# A continuación, vamos a repetir el experimento para 2000 pasos, manteniendo el número de runs.

# %%
results_ex1_2 = execute_bandit_experiment(k=10, steps=2000, runs=runs, bandit=bandit)
# Out:
# Bandit with 10 arms: ArmBinomial(n=10, p=0.25), ArmBinomial(n=10, p=0.6), ArmBinomial(n=10, p=0.45), ArmBinomial(n=10, p=0.72), ArmBinomial(n=10, p=0.73), ArmBinomial(n=10, p=0.32), ArmBinomial(n=10, p=0.74), ArmBinomial(n=10, p=0.87), ArmBinomial(n=10, p=0.8), ArmBinomial(n=10, p=0.39)
# Optimal arm for bandit is: 8 with expected reward=8.7
#
# Algoritmo EpsilonGreedy (epsilon=0): 83.00% de elecciones óptimas en el 20% último de steps
# Algoritmo EpsilonGreedy (epsilon=0): 339.21 de arrepentimiento acumulado
#
# Algoritmo EpsilonGreedy (epsilon=0.01): 81.56% de elecciones óptimas en el 20% último de steps
# Algoritmo EpsilonGreedy (epsilon=0.01): 1780.35 de arrepentimiento acumulado
#
# Algoritmo EpsilonGreedy (epsilon=0.1): 90.99% de elecciones óptimas en el 20% último de steps
# Algoritmo EpsilonGreedy (epsilon=0.1): 765.21 de arrepentimiento acumulado
#
# Algoritmo UCB1 (c=0.5): 97.41% de elecciones óptimas en el 20% último de steps
# Algoritmo UCB1 (c=0.5): 80.57 de arrepentimiento acumulado
#
# Algoritmo UCB1 (c=1): 99.52% de elecciones óptimas en el 20% último de steps
# Algoritmo UCB1 (c=1): 79.69 de arrepentimiento acumulado
#
# Algoritmo UCB1 (c=2): 97.56% de elecciones óptimas en el 20% último de steps
# Algoritmo UCB1 (c=2): 247.69 de arrepentimiento acumulado
#
# Algoritmo Softmax (temperature=0.5): 15.53% de elecciones óptimas en el 20% último de steps
# Algoritmo Softmax (temperature=0.5): 3351.23 de arrepentimiento acumulado
#
# Algoritmo Softmax (temperature=1): 42.83% de elecciones óptimas en el 20% último de steps
# Algoritmo Softmax (temperature=1): 1644.19 de arrepentimiento acumulado
#
# Algoritmo Softmax (temperature=2): 26.83% de elecciones óptimas en el 20% último de steps
# Algoritmo Softmax (temperature=2): 2580.68 de arrepentimiento acumulado
#
# Algoritmo EpsilonGreedy (epsilon=0): 83.00% de elecciones óptimas en el 20% último de steps
# Algoritmo EpsilonGreedy (epsilon=0): 339.21 de arrepentimiento acumulado
#
# Algoritmo EpsilonGreedy (epsilon=0.01): 81.56% de elecciones óptimas en el 20% último de steps
# Algoritmo EpsilonGreedy (epsilon=0.01): 1780.35 de arrepentimiento acumulado
#
# Algoritmo EpsilonGreedy (epsilon=0.1): 90.99% de elecciones óptimas en el 20% último de steps
# Algoritmo EpsilonGreedy (epsilon=0.1): 765.21 de arrepentimiento acumulado
#
# Algoritmo UCB1 (c=0.5): 97.41% de elecciones óptimas en el 20% último de steps
# Algoritmo UCB1 (c=0.5): 80.57 de arrepentimiento acumulado
#
# Algoritmo UCB1 (c=1): 99.52% de elecciones óptimas en el 20% último de steps
# Algoritmo UCB1 (c=1): 79.69 de arrepentimiento acumulado
#
# Algoritmo UCB1 (c=2): 97.56% de elecciones óptimas en el 20% último de steps
# Algoritmo UCB1 (c=2): 247.69 de arrepentimiento acumulado
#
# Algoritmo Softmax (temperature=0.5): 15.53% de elecciones óptimas en el 20% último de steps
# Algoritmo Softmax (temperature=0.5): 3351.23 de arrepentimiento acumulado
#
# Algoritmo Softmax (temperature=1): 42.83% de elecciones óptimas en el 20% último de steps
# Algoritmo Softmax (temperature=1): 1644.19 de arrepentimiento acumulado
#
# Algoritmo Softmax (temperature=2): 26.83% de elecciones óptimas en el 20% último de steps
# Algoritmo Softmax (temperature=2): 2580.68 de arrepentimiento acumulado

# %% [markdown]
# ### Valoración de los resultados
#
# Vemos un comportamiento similar al del apartado anterior, donde predomina UCB-1 con c=1, seguido por UCB-1 con c=2.
#
# Haber incrementado el número de pasos no parece ofrecer ningún beneficio significativo a las variantes de UCB o para EpsilonGreedy con epsilon=0.1. Sin embargo, para la variante con epsilon=0.01, que trata de "explotar" mucho más que de explorar otros brazos, vemos como a la larga el incremento en el número de pasos si que es altamente beneficiosa.

# %% [markdown]
# ### Promedio de elecciones óptimas por algoritmo
#
# Se presentan los promedios por algoritmo para esta primera variante del bandido. Los promedios están el línea con lo visualizado en las gráficas, con el algoritmo UCB-1 situándose a la cabeza (hay muy poca diferencia para distintos valores de c), y Epsilon-Greedy con epsilon=0.1 ofreciendo también un buen desempeño.

# %%
avg_results_ex1 = get_results_average(results_ex1_1, results_ex1_2)
for algorithm_name, avg_rate in avg_results_ex1.items():
    print(f"Algoritmo {algorithm_name}: {avg_rate:.2f}% promedio de elecciones óptimas en el 20% último de steps")
# Out:
# Algoritmo EpsilonGreedy (epsilon=0): 84.25% promedio de elecciones óptimas en el 20% último de steps
# Algoritmo EpsilonGreedy (epsilon=0.01): 68.21% promedio de elecciones óptimas en el 20% último de steps
# Algoritmo EpsilonGreedy (epsilon=0.1): 90.32% promedio de elecciones óptimas en el 20% último de steps
# Algoritmo UCB1 (c=0.5): 97.16% promedio de elecciones óptimas en el 20% último de steps
# Algoritmo UCB1 (c=1): 99.15% promedio de elecciones óptimas en el 20% último de steps
# Algoritmo UCB1 (c=2): 96.39% promedio de elecciones óptimas en el 20% último de steps
# Algoritmo Softmax (temperature=0.5): 14.77% promedio de elecciones óptimas en el 20% último de steps
# Algoritmo Softmax (temperature=1): 40.72% promedio de elecciones óptimas en el 20% último de steps
# Algoritmo Softmax (temperature=2): 26.85% promedio de elecciones óptimas en el 20% último de steps

# %% [markdown]
# ## Ejecución del experimento para Variante 2 del bandido
#
# Nos disponemos a realizar el experimento para un bandido de 20 brazos, manteniendo la distribución binomial con valor máximo 10.

# %%
# Definimos el bandido (se comparte entre experimentos)
bandit = Bandit(arms=ArmBinomial.generate_arms(k=20, n=10)) # Generar un bandido con k brazos de distribución binomial. El valor de máxima recompensa será 10

# %% [markdown]
# ### Ejecución de los algoritmos para 1000 steps
#
# Vamos a llevar a cabo el experimento con la nueva variante del bandido para 1000 pasos.

# %%
results_ex2_1 = execute_bandit_experiment(k=20, steps=1000, runs=runs, bandit=bandit)
# Out:
# Bandit with 20 arms: ArmBinomial(n=10, p=0.7), ArmBinomial(n=10, p=0.39), ArmBinomial(n=10, p=0.62), ArmBinomial(n=10, p=0.65), ArmBinomial(n=10, p=0.67), ArmBinomial(n=10, p=0.81), ArmBinomial(n=10, p=0.75), ArmBinomial(n=10, p=0.84), ArmBinomial(n=10, p=0.64), ArmBinomial(n=10, p=0.46), ArmBinomial(n=10, p=0.77), ArmBinomial(n=10, p=0.66), ArmBinomial(n=10, p=0.36), ArmBinomial(n=10, p=0.15), ArmBinomial(n=10, p=0.71), ArmBinomial(n=10, p=0.89), ArmBinomial(n=10, p=0.49), ArmBinomial(n=10, p=0.74), ArmBinomial(n=10, p=0.41), ArmBinomial(n=10, p=0.58)
# Optimal arm for bandit is: 16 with expected reward=8.9
#
# Algoritmo EpsilonGreedy (epsilon=0): 69.50% de elecciones óptimas en el 20% último de steps
# Algoritmo EpsilonGreedy (epsilon=0): 231.88 de arrepentimiento acumulado
#
# Algoritmo EpsilonGreedy (epsilon=0.01): 29.60% de elecciones óptimas en el 20% último de steps
# Algoritmo EpsilonGreedy (epsilon=0.01): 1198.88 de arrepentimiento acumulado
#
# Algoritmo EpsilonGreedy (epsilon=0.1): 81.22% de elecciones óptimas en el 20% último de steps
# Algoritmo EpsilonGreedy (epsilon=0.1): 524.63 de arrepentimiento acumulado
#
# Algoritmo UCB1 (c=0.5): 96.91% de elecciones óptimas en el 20% último de steps
# Algoritmo UCB1 (c=0.5): 103.81 de arrepentimiento acumulado
#
# Algoritmo UCB1 (c=1): 97.69% de elecciones óptimas en el 20% último de steps
# Algoritmo UCB1 (c=1): 159.38 de arrepentimiento acumulado
#
# Algoritmo UCB1 (c=2): 87.72% de elecciones óptimas en el 20% último de steps
# Algoritmo UCB1 (c=2): 411.17 de arrepentimiento acumulado
#
# Algoritmo Softmax (temperature=0.5): 4.86% de elecciones óptimas en el 20% último de steps
# Algoritmo Softmax (temperature=0.5): 1893.47 de arrepentimiento acumulado
#
# Algoritmo Softmax (temperature=1): 18.92% de elecciones óptimas en el 20% último de steps
# Algoritmo Softmax (temperature=1): 1222.74 de arrepentimiento acumulado
#
# Algoritmo Softmax (temperature=2): 13.98% de elecciones óptimas en el 20% último de steps
# Algoritmo Softmax (temperature=2): 1623.73 de arrepentimiento acumulado
#
# Algoritmo EpsilonGreedy (epsilon=0): 69.50% de elecciones óptimas en el 20% último de steps
# Algoritmo EpsilonGreedy (epsilon=0): 231.88 de arrepentimiento acumulado
#
# Algoritmo EpsilonGreedy (epsilon=0.01): 29.60% de elecciones óptimas en el 20% último de steps
# Algoritmo EpsilonGreedy (epsilon=0.01): 1198.88 de arrepentimiento acumulado
#
# Algoritmo EpsilonGreedy (epsilon=0.1): 81.22% de elecciones óptimas en el 20% último de steps
# Algoritmo EpsilonGreedy (epsilon=0.1): 524.63 de arrepentimiento acumulado
#
# Algoritmo UCB1 (c=0.5): 96.91% de elecciones óptimas en el 20% último de steps
# Algoritmo UCB1 (c=0.5): 103.81 de arrepentimiento acumulado
#
# Algoritmo UCB1 (c=1): 97.69% de elecciones óptimas en el 20% último de steps
# Algoritmo UCB1 (c=1): 159.38 de arrepentimiento acumulado
#
# Algoritmo UCB1 (c=2): 87.72% de elecciones óptimas en el 20% último de steps
# Algoritmo UCB1 (c=2): 411.17 de arrepentimiento acumulado
#
# Algoritmo Softmax (temperature=0.5): 4.86% de elecciones óptimas en el 20% último de steps
# Algoritmo Softmax (temperature=0.5): 1893.47 de arrepentimiento acumulado
#
# Algoritmo Softmax (temperature=1): 18.92% de elecciones óptimas en el 20% último de steps
# Algoritmo Softmax (temperature=1): 1222.74 de arrepentimiento acumulado
#
# Algoritmo Softmax (temperature=2): 13.98% de elecciones óptimas en el 20% último de steps
# Algoritmo Softmax (temperature=2): 1623.73 de arrepentimiento acumulado

# %% [markdown]
# ### Valoración de los resultados
#
# Vemos en esta ejecución como, al existir un número superior de brazos, a los algoritmos Epsilon-Greedy les cuesta más, incluso con una componente exploratoria marcada, llegar a identificar cuál es el que aporta mayor recompensa. Sin embargo, las variantes de UCB-1 vuelven a identificar el mejor brazo en los 400 primeros pasos aproximadamente, resultando los mejores en este caso también aquellos con c=0.5 y c=1.

# %% [markdown]
# ### Ejecución de los algoritmos para 2000 steps
#
# A continuación, vamos a repetir el experimento para 2000 pasos, manteniendo el número de runs.

# %%
results_ex2_2 = execute_bandit_experiment(k=20, steps=2000, runs=runs, bandit=bandit)
# Out:
# Bandit with 20 arms: ArmBinomial(n=10, p=0.7), ArmBinomial(n=10, p=0.39), ArmBinomial(n=10, p=0.62), ArmBinomial(n=10, p=0.65), ArmBinomial(n=10, p=0.67), ArmBinomial(n=10, p=0.81), ArmBinomial(n=10, p=0.75), ArmBinomial(n=10, p=0.84), ArmBinomial(n=10, p=0.64), ArmBinomial(n=10, p=0.46), ArmBinomial(n=10, p=0.77), ArmBinomial(n=10, p=0.66), ArmBinomial(n=10, p=0.36), ArmBinomial(n=10, p=0.15), ArmBinomial(n=10, p=0.71), ArmBinomial(n=10, p=0.89), ArmBinomial(n=10, p=0.49), ArmBinomial(n=10, p=0.74), ArmBinomial(n=10, p=0.41), ArmBinomial(n=10, p=0.58)
# Optimal arm for bandit is: 16 with expected reward=8.9
#
# Algoritmo EpsilonGreedy (epsilon=0): 70.00% de elecciones óptimas en el 20% último de steps
# Algoritmo EpsilonGreedy (epsilon=0): 405.33 de arrepentimiento acumulado
#
# Algoritmo EpsilonGreedy (epsilon=0.01): 45.89% de elecciones óptimas en el 20% último de steps
# Algoritmo EpsilonGreedy (epsilon=0.01): 1690.20 de arrepentimiento acumulado
#
# Algoritmo EpsilonGreedy (epsilon=0.1): 85.80% de elecciones óptimas en el 20% último de steps
# Algoritmo EpsilonGreedy (epsilon=0.1): 842.86 de arrepentimiento acumulado
#
# Algoritmo UCB1 (c=0.5): 93.91% de elecciones óptimas en el 20% último de steps
# Algoritmo UCB1 (c=0.5): 146.29 de arrepentimiento acumulado
#
# Algoritmo UCB1 (c=1): 99.08% de elecciones óptimas en el 20% último de steps
# Algoritmo UCB1 (c=1): 165.29 de arrepentimiento acumulado
#
# Algoritmo UCB1 (c=2): 93.48% de elecciones óptimas en el 20% último de steps
# Algoritmo UCB1 (c=2): 499.11 de arrepentimiento acumulado
#
# Algoritmo Softmax (temperature=0.5): 8.74% de elecciones óptimas en el 20% último de steps
# Algoritmo Softmax (temperature=0.5): 3743.77 de arrepentimiento acumulado
#
# Algoritmo Softmax (temperature=1): 19.97% de elecciones óptimas en el 20% último de steps
# Algoritmo Softmax (temperature=1): 2295.06 de arrepentimiento acumulado
#
# Algoritmo Softmax (temperature=2): 14.23% de elecciones óptimas en el 20% último de steps
# Algoritmo Softmax (temperature=2): 3198.85 de arrepentimiento acumulado
#
# Algoritmo EpsilonGreedy (epsilon=0): 70.00% de elecciones óptimas en el 20% último de steps
# Algoritmo EpsilonGreedy (epsilon=0): 405.33 de arrepentimiento acumulado
#
# Algoritmo EpsilonGreedy (epsilon=0.01): 45.89% de elecciones óptimas en el 20% último de steps
# Algoritmo EpsilonGreedy (epsilon=0.01): 1690.20 de arrepentimiento acumulado
#
# Algoritmo EpsilonGreedy (epsilon=0.1): 85.80% de elecciones óptimas en el 20% último de steps
# Algoritmo EpsilonGreedy (epsilon=0.1): 842.86 de arrepentimiento acumulado
#
# Algoritmo UCB1 (c=0.5): 93.91% de elecciones óptimas en el 20% último de steps
# Algoritmo UCB1 (c=0.5): 146.29 de arrepentimiento acumulado
#
# Algoritmo UCB1 (c=1): 99.08% de elecciones óptimas en el 20% último de steps
# Algoritmo UCB1 (c=1): 165.29 de arrepentimiento acumulado
#
# Algoritmo UCB1 (c=2): 93.48% de elecciones óptimas en el 20% último de steps
# Algoritmo UCB1 (c=2): 499.11 de arrepentimiento acumulado
#
# Algoritmo Softmax (temperature=0.5): 8.74% de elecciones óptimas en el 20% último de steps
# Algoritmo Softmax (temperature=0.5): 3743.77 de arrepentimiento acumulado
#
# Algoritmo Softmax (temperature=1): 19.97% de elecciones óptimas en el 20% último de steps
# Algoritmo Softmax (temperature=1): 2295.06 de arrepentimiento acumulado
#
# Algoritmo Softmax (temperature=2): 14.23% de elecciones óptimas en el 20% último de steps
# Algoritmo Softmax (temperature=2): 3198.85 de arrepentimiento acumulado

# %% [markdown]
# ### Promedio de elecciones óptimas por algoritmo
#
# Se presentan los promedios por algoritmo para esta segunda variante del bandido.

# %%
avg_results_ex2 = get_results_average(results_ex2_1, results_ex2_2)
for algorithm_name, avg_rate in avg_results_ex2.items():
    print(f"Algoritmo {algorithm_name}: {avg_rate:.2f}% promedio de elecciones óptimas en el 20% último de steps")
# Out:
# Algoritmo EpsilonGreedy (epsilon=0): 69.75% promedio de elecciones óptimas en el 20% último de steps
# Algoritmo EpsilonGreedy (epsilon=0.01): 37.75% promedio de elecciones óptimas en el 20% último de steps
# Algoritmo EpsilonGreedy (epsilon=0.1): 83.51% promedio de elecciones óptimas en el 20% último de steps
# Algoritmo UCB1 (c=0.5): 95.41% promedio de elecciones óptimas en el 20% último de steps
# Algoritmo UCB1 (c=1): 98.39% promedio de elecciones óptimas en el 20% último de steps
# Algoritmo UCB1 (c=2): 90.60% promedio de elecciones óptimas en el 20% último de steps
# Algoritmo Softmax (temperature=0.5): 6.80% promedio de elecciones óptimas en el 20% último de steps
# Algoritmo Softmax (temperature=1): 19.45% promedio de elecciones óptimas en el 20% último de steps
# Algoritmo Softmax (temperature=2): 14.11% promedio de elecciones óptimas en el 20% último de steps

# %% [markdown]
# ### Valoración de los resultados
#
# Tras 2000 pasos, vemos como el algoritmo de Epsilon-greedy con un 10% de probabilidad de explorar brazos nuevos, se acerca mucho más a la solución óptima, lo cual era esperable. Para las variantes con un epsilon menor, vemos como mejora de forma mucho más lenta para epsilon=0.01, y como se vuelve a estancar para epsilon=0.
#
# En cuanto a las variantes que emplean UCB-1, vemos como alcanzan una solución óptima muchísimo más rápido, siendo incluso innecesarios 2000 pasos puesto que en 1000, como hemos visto en el apartado anterior, ya habían conseguido determinar cuál es el brazo óptimo. Confirmamos por tanto que siguen siendo los que mejor funcionan.

# %% [markdown]
# ### Promedios totales de elecciones óptimas por algoritmo para todos los experimentos

# %%
for algorithm_name, avg_rate in get_results_average(avg_results_ex1, avg_results_ex2).items():
    print(f"Algoritmo {algorithm_name}: {avg_rate:.2f}% promedio total de elecciones óptimas en el 20% último de steps")
# Out:
# Algoritmo EpsilonGreedy (epsilon=0): 77.00% promedio total de elecciones óptimas en el 20% último de steps
# Algoritmo EpsilonGreedy (epsilon=0.01): 52.98% promedio total de elecciones óptimas en el 20% último de steps
# Algoritmo EpsilonGreedy (epsilon=0.1): 86.91% promedio total de elecciones óptimas en el 20% último de steps
# Algoritmo UCB1 (c=0.5): 96.28% promedio total de elecciones óptimas en el 20% último de steps
# Algoritmo UCB1 (c=1): 98.77% promedio total de elecciones óptimas en el 20% último de steps
# Algoritmo UCB1 (c=2): 93.50% promedio total de elecciones óptimas en el 20% último de steps
# Algoritmo Softmax (temperature=0.5): 10.78% promedio total de elecciones óptimas en el 20% último de steps
# Algoritmo Softmax (temperature=1): 30.08% promedio total de elecciones óptimas en el 20% último de steps
# Algoritmo Softmax (temperature=2): 20.48% promedio total de elecciones óptimas en el 20% último de steps

# %% [markdown]
# ## Conclusiones
#
# Hemos realizado distintos experimentos para el bandido de k-brazos siguiendo una distribución binomial:
#
# *  Experimento para bandido con K=10, steps=1000
# *  Experimento para bandido con K=10, steps=2000
# *  Experimento para bandido con K=20, steps=1000
# *  Experimento para bandido con K=20, steps=2000
#
# En todos los casos se han comparado distintas variantes del algoritmo Epsilon-Greedy, con epsilon=[0, 0.01, 0.1], el algoritmo UCB-1 con c=[0.5, 1, 2], y el algoritmo Softmax. Los parámetros han sido siempre los mismos para asegurar la consistencia de los resultados.
#
# Siendo así, tenemos que, en todos los casos, los algoritmos que mejor comporamiento (Porcentaje de aciertos en último 20% de pasos vs rechazo acumulado) ha presentado han sido los algoritmos UCB-1 con c=0.5 y c=1.
#
# Para los algoritmos Epsilon-Greedy, vemos como interesa tener un nivel de exploración moderado (ej. epsilon=0.1) para obtener los mejores resultados, aunque suelen quedar sensiblemente por debajo de los resultados de UCB-1, y necesitan un número superior de pasos para descubrir el brazo óptimo que UCB.
