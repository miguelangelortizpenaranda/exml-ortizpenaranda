# %% [markdown]
# # Experimentos para Bandido de K-Brazos

# %% [markdown]
# [Bandido de K-Brazos con distribución normal](bandit_experiment_normal.ipynb) \
# [Bandido de K-Brazos con distribución binomial](bandit_experiment_binomial.ipynb) \
# [Bandido de K-Brazos con distribución de Bernoulli](bandit_experiment_bernoulli.ipynb)
