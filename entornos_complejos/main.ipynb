# %% [markdown]
# # Experimentos para Aprendizaje por Refuerzo en Entornos Complejos
#
# **Alumno:** Miguel Ángel Ortiz Peñaranda
#
# Se referencian a continuación los experimentos realizados sobre métodos tabulares y métodos aproximados. Dentro del notebook
# de cada experimento se explica con más detalle en qué consite.
#
# ## Métodos Tabulares
# [Modelos Tabulares - Frozen Lake](frozen_lake.ipynb) \
# [Modelos Tabulares - Taxi](taxi.ipynb)
#
# ## Métodos aproximados
# [Modelos Aproximados - Mountain Car](mountain_car.ipynb)
