# %% [markdown]
# <a href="https://colab.research.google.com/github/miguelangelortizpenaranda/exml-ortizpenaranda/blob/main/main.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Extensiones de Machine Learning - Aprendizaje por refuerzo
#
# **Alumno:** Miguel Ángel Ortiz Peñaranda
#
# En este notebook se referencian las partes correspondientes al Bandido de K-Brazos y Aprendizaje en Entornos Complejos correspondientes
# a la asignatura de Extensiones de Machine Learning. Los distintos experimentos son referenciados en los `main.py` de cada parte. En cada experimento se explica en detalle en qué consiste, la metodología de trabajo y la estructura del mismo.
#
# El apartado de Aprendizaje en Entornos complejos comparte el mismo subdirectorio, puesto que hay código común a la parte de métodos tabulares y métodos aproximados, y de esta forma se favorece la simplicidad.
#
# A continuación se exponen los enlaces a ambas partes:
#
# [Ir a Bandido de K-Brazos](k_brazos/main.ipynb)
#
# [Ir a Aprendizaje en Entornos Complejos](entornos_complejos/main.ipynb)
